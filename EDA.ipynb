# %%
# sometimes we need this --> %matplot_inline
# %pylab inline
#%pylab.rcParams['figure.figsize'] = (10, 6)
from eda import *
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# A graph showing how many people is hearing songs at some time of the day.

# %%
times()

# %% [markdown]
# A graph showing how much the people decides to hear or not the songs they are recommended.

# %%
age_skip_song()

# %% [markdown]
# # EDA on ids columns related to songs

# %% [markdown]
# Here some plots to give us an idea on how to implement the clustering.

# %%
from clustering import *
scatterplot('media_id', 'genre_id', 'artist_id')
