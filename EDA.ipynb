# %%
# sometimes we need this --> %matplot_inline
# %pylab inline
#%pylab.rcParams['figure.figsize'] = (10, 6)
from eda import *
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# A graph showing how many people is hearing songs at some time of the day.

# %%
times()

# %% [markdown]
# A graph showing how much the people decides to hear or not the songs they are recommended.

# %%
age_skip_song()

# %% [markdown]
# # Clustering for columns with ids

# %% [markdown]
# **Very important:** The columns `genre_id` and `user_id` have some ids equal to zero. So, we are ignoring those rows. Could be good idea to _fill them_.
